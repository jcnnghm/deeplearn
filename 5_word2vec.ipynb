# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'term', 'originated', 'anarchism', 'originated', 'term', 'as', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default():

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# WARNING:tensorflow:From <ipython-input-10-01669d5c739a>:4: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Initialized
# Average loss at step 0: 8.408265
# Nearest to up: positron, tiryns, dave, crystals, censure, sgml, unstructured, suppressed,
# Nearest to other: quattro, supply, warheads, amphetamines, sunni, kind, amis, tramway,
# Nearest to and: simo, impaled, applet, reunification, cosmography, impiety, meaningfully, analysis,
# Nearest to been: scoring, kearney, quartz, stimulate, toured, burnside, arrears, ghamdi,
# Nearest to united: addams, electrochemical, poems, duchies, geology, gorgon, yerba, blair,
# Nearest to new: kids, habitable, calves, lande, substitution, eddic, irma, bridge,
# Nearest to also: peptides, nibelungenlied, ruined, jb, gascon, pellet, sabre, katal,
# Nearest to can: hierarchical, faxes, euclid, archaeopteryx, limehouse, chilean, rather, ostracism,
# Nearest to may: panama, nite, biodiversity, behe, plurality, exclusivity, disapproved, lowe,
# Nearest to american: witherspoon, childbirth, wladislaus, kublai, fads, tentacle, fi, bun,
# Nearest to for: ruins, asylum, afforded, telling, yankees, tribute, blender, trapezohedron,
# Nearest to have: geraldine, nutritious, austin, muentzer, emphasised, dziga, alligator, commutation,
# Nearest to is: reluctantly, votes, dalnet, junichiro, locomotion, supergirl, hin, mpv,
# Nearest to used: hazaras, vane, cautioned, pons, lotharingia, ebbets, gabal, delays,
# Nearest to that: competing, debuted, obliterated, sophist, inward, keynes, widowers, concern,
# Nearest to more: valour, an, monopoles, monoclonal, wager, sophia, undertones, supranationalism,
# Average loss at step 2000: 4.251334
# Average loss at step 4000: 3.704440
# Average loss at step 6000: 3.781222
# Average loss at step 8000: 3.706478
# Average loss at step 10000: 3.630329
# Nearest to up: office, refers, them, censure, pregnant, suppressed, not, positron,
# Nearest to other: sunni, kind, nonstop, wanderers, woodbridge, family, moved, aligning,
# Nearest to and: or, who, which, in, trill, he, typically, the,
# Nearest to been: pathologist, propagating, longer, was, rooster, assisting, hopeful, represent,
# Nearest to united: addams, duchies, monosaccharide, twas, kimmei, gorgon, electrochemical, harem,
# Nearest to new: habitable, calves, substitution, slumberland, kids, chairmanship, uk, adl,
# Nearest to also: who, which, not, yan, indus, maldivian, could, lusitani,
# Nearest to can: may, rather, hierarchical, faxes, zef, postmaster, would, resonated,
# Nearest to may: would, can, plurality, must, refraction, systematics, possibilities, exclusivity,
# Nearest to american: witherspoon, praising, d, habitations, notoriously, ry, and, rags,
# Nearest to for: by, newly, cryptographer, suburbs, as, passionate, including, sixty,
# Nearest to have: had, be, are, were, has, bicycles, like, strongly,
# Nearest to is: was, are, has, as, genuine, does, liquefaction, parse,
# Nearest to used: vane, ego, cinnamon, impossible, found, spliced, lotharingia, assigned,
# Nearest to that: which, where, competing, harmonica, outgoing, ppt, this, it,
# Nearest to more: valour, bmw, amassed, diluted, monopoles, fashion, medieval, an,
# Average loss at step 12000: 3.601710
# Average loss at step 14000: 3.622667
# Average loss at step 16000: 3.547758
# Average loss at step 18000: 3.619371
# Average loss at step 20000: 3.538284
# Nearest to up: them, office, refers, him, censure, nitrogen, storylines, proportional,
# Nearest to other: different, various, harvey, these, many, sure, woodbridge, wanderers,
# Nearest to and: or, but, who, in, ed, from, botched, which,
# Nearest to been: be, was, were, become, propagating, had, by, assisting,
# Nearest to united: addams, harem, duchies, kimmei, spp, dinoflagellates, monosaccharide, gorgon,
# Nearest to new: habitable, slumberland, adl, calves, substitution, vinyl, uk, malaysians,
# Nearest to also: who, which, massage, trails, maldivian, often, not, there,
# Nearest to can: may, could, would, will, must, resonated, should, might,
# Nearest to may: can, would, must, will, could, should, might, antes,
# Nearest to american: witherspoon, praising, german, ry, habitations, culloden, indian, toasting,
# Nearest to for: newly, against, indulge, cortes, cryptographer, on, rpr, as,
# Nearest to have: had, has, be, are, were, bicycles, like, austin,
# Nearest to is: was, has, are, does, became, be, manifesting, kilometer,
# Nearest to used: known, found, ego, cinnamon, vane, spliced, referred, seen,
# Nearest to that: which, this, what, however, but, where, therefore, harmonica,
# Nearest to more: less, diluted, most, valour, penh, monopoles, bmw, amassed,
# Average loss at step 22000: 3.564029
# Average loss at step 24000: 3.349252
# Average loss at step 26000: 3.542026
# Average loss at step 28000: 3.475929
# Average loss at step 30000: 3.489352
# Nearest to up: them, him, office, back, proportional, refers, censure, out,
# Nearest to other: various, different, harvey, cytosol, woodbridge, rajons, wissenschaft, previous,
# Nearest to and: or, but, bamako, seemingly, holds, botched, across, which,
# Nearest to been: be, become, were, was, had, naboth, assisting, propagating,
# Nearest to united: addams, spp, kimmei, dinoflagellates, harem, duchies, twas, netherland,
# Nearest to new: habitable, adl, superpowered, belizean, slumberland, leah, moral, karakoram,
# Nearest to also: which, often, who, sometimes, now, usually, there, massage,
# Nearest to can: may, could, will, would, must, should, might, resonated,
# Nearest to may: can, would, will, must, could, should, might, cannot,
# Nearest to american: german, french, indian, praising, chancery, ry, bistable, habitations,
# Nearest to for: including, newly, pollinators, as, of, rinpoche, neutral, cryptographer,
# Nearest to have: had, has, be, were, are, believe, strongly, provide,
# Nearest to is: was, has, are, if, does, dingo, rejoined, became,
# Nearest to used: known, found, seen, cinnamon, referred, spliced, responsible, ego,
# Nearest to that: which, however, what, but, this, where, outgoing, fittingly,
# Nearest to more: less, most, very, diluted, penh, picnics, certify, greater,
# Average loss at step 32000: 3.486379
# Average loss at step 34000: 3.441163
# Average loss at step 36000: 3.432296
# Average loss at step 38000: 3.414970
# Average loss at step 40000: 3.457627
# Nearest to up: them, out, back, him, off, tribunes, proportional, voodoo,
# Nearest to other: various, different, many, harvey, underestimate, woodbridge, hallmarks, rajons,
# Nearest to and: in, or, but, loneliness, s, of, however, affaires,
# Nearest to been: be, become, was, were, facilitator, had, being, harriman,
# Nearest to united: addams, kimmei, usa, spp, duchies, libyan, balloons, dinoflagellates,
# Nearest to new: bedroom, superpowered, giants, fleurs, nmi, habitable, hemisphere, yd,
# Nearest to also: which, often, sometimes, still, who, actually, there, now,
# Nearest to can: may, could, will, would, must, might, should, resonated,
# Nearest to may: can, would, will, must, could, might, should, resonated,
# Nearest to american: british, indian, german, chancery, praising, spawned, international, ry,
# Nearest to for: cryptographer, against, including, by, pollinators, newly, through, although,
# Nearest to have: had, has, were, be, are, provide, include, believe,
# Nearest to is: was, are, has, if, became, does, parse, rejoined,
# Nearest to used: known, found, referred, seen, nuggets, spliced, responsible, cinnamon,
# Nearest to that: which, however, this, where, competing, what, fad, mainframes,
# Nearest to more: less, most, very, diluted, rather, mckinley, percentile, not,
# Average loss at step 42000: 3.478433
# Average loss at step 44000: 3.449527
# Average loss at step 46000: 3.456484
# Average loss at step 48000: 3.394557
# Average loss at step 50000: 3.150389
# Nearest to up: out, them, off, down, back, tribunes, him, voodoo,
# Nearest to other: various, different, many, underestimate, harvey, several, others, dms,
# Nearest to and: or, but, including, in, while, however, since, from,
# Nearest to been: be, become, was, were, had, are, facilitator, harriman,
# Nearest to united: within, kimmei, senate, addams, usa, spp, following, duchies,
# Nearest to new: superpowered, fleurs, giants, third, motor, massive, conglomerates, oas,
# Nearest to also: still, now, often, sometimes, which, there, massage, actually,
# Nearest to can: may, could, would, will, must, might, should, cannot,
# Nearest to may: can, would, will, could, must, might, should, cannot,
# Nearest to american: indian, german, british, whose, alleys, ale, ihra, ry,
# Nearest to for: cryptographer, including, hydrology, of, through, against, telling, after,
# Nearest to have: had, has, were, are, be, provide, include, eugenicist,
# Nearest to is: was, has, are, became, eid, be, were, parse,
# Nearest to used: known, found, referred, spliced, called, considered, written, assigned,
# Nearest to that: which, however, this, where, what, fad, it, but,
# Nearest to more: less, most, very, greater, diluted, rather, penh, valour,
# Average loss at step 52000: 3.447733
# Average loss at step 54000: 3.423400
# Average loss at step 56000: 3.382893
# Average loss at step 58000: 3.427575
# Average loss at step 60000: 3.385992
# Nearest to up: them, out, off, back, him, down, tribunes, rose,
# Nearest to other: various, different, many, some, others, underestimate, harvey, including,
# Nearest to and: or, but, including, kankan, org, imitated, moire, depot,
# Nearest to been: become, be, was, were, survived, come, had, facilitator,
# Nearest to united: senate, kimmei, usa, addams, duchies, within, polidori, spp,
# Nearest to new: abruzzo, superpowered, microwaves, fleurs, kh, moral, leah, different,
# Nearest to also: often, sometimes, which, still, now, massage, usually, never,
# Nearest to can: may, could, will, would, must, might, cannot, should,
# Nearest to may: can, would, will, must, could, might, should, cannot,
# Nearest to american: british, german, indian, african, alleys, praising, miniseries, french,
# Nearest to for: cryptographer, pollinators, including, without, after, while, whampoa, commited,
# Nearest to have: had, has, were, be, provide, are, having, include,
# Nearest to is: was, has, are, became, does, requires, remains, parse,
# Nearest to used: known, found, referred, seen, written, responsible, nuggets, available,
# Nearest to that: which, however, competing, where, what, phrases, themis, fad,
# Nearest to more: less, most, very, rather, greater, diluted, too, valour,
# Average loss at step 62000: 3.372109
# Average loss at step 64000: 3.335454
# Average loss at step 66000: 3.383938
# Average loss at step 68000: 3.409329
# Average loss at step 70000: 3.441353
# Nearest to up: out, off, them, back, down, him, tribunes, voodoo,
# Nearest to other: various, different, others, carnarvon, underestimate, harvey, individual, including,
# Nearest to and: or, but, while, bamako, including, allgemeine, however, which,
# Nearest to been: become, be, was, previously, come, were, already, facilitator,
# Nearest to united: senate, usa, addams, kimmei, duchies, following, yokoi, buffalo,
# Nearest to new: microwaves, superpowered, adl, wider, abruzzo, centres, revelations, hol,
# Nearest to also: often, sometimes, still, now, which, never, largely, massage,
# Nearest to can: may, will, could, would, must, might, cannot, should,
# Nearest to may: can, will, could, would, must, might, should, cannot,
# Nearest to american: british, german, french, italian, australian, indian, canadian, educational,
# Nearest to for: cryptographer, while, including, through, of, in, without, mutt,
# Nearest to have: had, has, be, were, are, include, having, provide,
# Nearest to is: was, has, are, became, does, eid, be, becomes,
# Nearest to used: known, referred, found, responsible, available, seen, required, written,
# Nearest to that: which, however, where, what, this, competing, fad, often,
# Nearest to more: less, most, rather, very, too, greater, diluted, extremely,
# Average loss at step 72000: 3.425010
# Average loss at step 74000: 3.381571
# Average loss at step 76000: 3.382996
# Average loss at step 78000: 3.388868
# Average loss at step 80000: 3.318518
# Nearest to up: out, off, them, back, down, him, together, regain,
# Nearest to other: various, different, including, underestimate, others, individual, rajons, carnarvon,
# Nearest to and: or, but, while, although, including, which, however, kankan,
# Nearest to been: become, be, was, already, were, previously, facilitator, had,
# Nearest to united: senate, usa, same, addams, kimmei, duchies, supreme, libyan,
# Nearest to new: superpowered, wider, microwaves, habitable, adl, saarc, moral, massive,
# Nearest to also: which, often, now, still, sometimes, usually, massage, largely,
# Nearest to can: could, may, will, would, must, might, should, cannot,
# Nearest to may: can, must, could, will, would, might, should, cannot,
# Nearest to american: british, german, italian, australian, canadian, indian, educational, alleys,
# Nearest to for: cryptographer, including, of, telling, macha, without, reboot, whampoa,
# Nearest to have: had, has, were, be, include, are, having, adair,
# Nearest to is: was, are, has, eid, became, be, concerted, remains,
# Nearest to used: known, referred, found, seen, responsible, required, considered, available,
# Nearest to that: which, however, what, fad, where, competing, but, clades,
# Nearest to more: less, most, rather, very, diluted, too, greater, longer,
# Average loss at step 82000: 3.349416
# Average loss at step 84000: 3.332596
# Average loss at step 86000: 3.312575
# Average loss at step 88000: 3.374649
# Average loss at step 90000: 3.346123
# Nearest to up: off, out, them, him, back, together, down, me,
# Nearest to other: various, others, different, many, several, individual, carnarvon, including,
# Nearest to and: or, but, although, while, s, who, including, however,
# Nearest to been: become, be, was, already, recently, come, were, had,
# Nearest to united: senate, usa, kimmei, obstinate, libyan, same, buffalo, addams,
# Nearest to new: superpowered, different, microwaves, abruzzo, separate, fleurs, adl, zhou,
# Nearest to also: still, sometimes, now, often, never, actually, massage, which,
# Nearest to can: could, may, will, would, must, might, should, cannot,
# Nearest to may: can, could, must, would, might, should, will, cannot,
# Nearest to american: british, german, italian, canadian, english, french, australian, ry,
# Nearest to for: after, without, including, cryptographer, hornblower, mutt, commited, while,
# Nearest to have: had, has, include, were, are, be, having, offer,
# Nearest to is: was, has, are, refers, became, be, requires, does,
# Nearest to used: referred, known, found, defined, available, published, held, written,
# Nearest to that: which, however, what, competing, posteriori, this, who, fittingly,
# Nearest to more: less, most, very, rather, too, greater, diluted, quite,
# Average loss at step 92000: 3.314696
# Average loss at step 94000: 3.410787
# Average loss at step 96000: 3.339886
# Average loss at step 98000: 3.182977
# Average loss at step 100000: 3.323024
# Nearest to up: off, out, them, him, down, back, together, voodoo,
# Nearest to other: including, different, various, individual, carnarvon, underestimate, others, sem,
# Nearest to and: or, although, but, however, like, in, including, since,
# Nearest to been: become, be, were, was, recently, had, facilitator, already,
# Nearest to united: senate, usa, obstinate, kimmei, libyan, buffalo, sitar, conseil,
# Nearest to new: fleurs, separate, abruzzo, different, adl, superpowered, microwaves, prey,
# Nearest to also: now, often, still, sometimes, generally, actually, usually, never,
# Nearest to can: could, may, will, must, would, should, might, cannot,
# Nearest to may: can, must, could, would, will, might, should, cannot,
# Nearest to american: british, german, italian, indian, australian, canadian, dutch, infrastructural,
# Nearest to for: without, including, commited, cryptographer, of, in, overlook, whampoa,
# Nearest to have: had, has, were, include, are, be, having, offer,
# Nearest to is: was, are, has, catolica, became, becomes, be, although,
# Nearest to used: known, referred, found, available, defined, required, seen, published,
# Nearest to that: which, however, what, also, clades, expectation, generally, phrases,
# Nearest to more: less, most, rather, very, diluted, greater, quite, longer,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch(batch_size, window_size=1):
  global data_index
  span = 2 * window_size + 1 # [window_size target window_size]
  batch = np.ndarray(shape=(batch_size, 2 * window_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)

  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
    
  for i in range(batch_size):
    batch[i,:window_size] = list(buffer)[:window_size]
    batch[i,window_size:] = list(buffer)[window_size+1:]
    labels[i] = buffer[window_size]
    
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
    
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

data_index = 0
batch, labels = generate_batch(batch_size=8, window_size=1)
print('    batch:', [[reverse_dictionary[bi] for bi in bd] for bd in batch])
print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of'], ['term', 'abuse'], ['of', 'first'], ['abuse', 'used'], ['first', 'against']]
#     labels: ['originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
window_size = 1
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default():

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, window_size * 2])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  # softmax_weights = tf.Variable(
  #  tf.truncated_normal([vocabulary_size, embedding_size * window_size * 2],
  #                       stddev=1.0 / math.sqrt(embedding_size)))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
    
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # embed = tf.reshape(embed, [batch_size, embedding_size * window_size * 2])
  embed = tf.reduce_sum(embed, 1)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(batch_size, window_size=window_size)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.430004
# Nearest to i: him, radiometer, malayo, waltz, defined, philanthropist, nis, roping,
# Nearest to united: moire, padawan, nihilo, impulsive, drayton, rumored, bradman, sausage,
# Nearest to four: turf, playoff, elvis, hee, vanishing, waid, polonia, megabytes,
# Nearest to which: intricately, folio, sumter, scratch, pushkin, reformulation, chukchi, supersymmetry,
# Nearest to not: breadth, signing, malevolent, carlton, cathodes, smit, harmala, later,
# Nearest to five: alpina, unabomber, shoes, druidism, demonstrative, creed, yury, sounded,
# Nearest to most: cimeti, asymptotic, deconstruction, cdb, doubtful, spinal, competitor, bali,
# Nearest to but: lewinsky, xxx, hira, simplified, expected, gimmicks, icao, microsoft,
# Nearest to d: warping, problematic, ot, photographic, berkman, avram, cynic, iv,
# Nearest to he: dormitories, lobo, kets, grooming, yield, objects, supported, zhu,
# Nearest to two: danforth, ohlin, livejournal, rastafari, joining, disturbs, simplifications, iwo,
# Nearest to so: wasted, glaukos, constructivists, hogg, burney, warheads, dnia, livy,
# Nearest to been: excepted, hurled, fink, doctors, kinsman, deduces, faq, liquidation,
# Nearest to his: predominance, timurid, resigning, waldo, stabilizes, striving, halmos, hash,
# Nearest to has: incurred, failed, contemporaneously, janis, dunkirk, adamant, ric, musicbrainz,
# Nearest to these: swordsmanship, jennie, topalov, predicates, complicity, rodrigues, chmielnicki, respondents,
# Average loss at step 2000: 3.978099
# Average loss at step 4000: 3.481156
# Average loss at step 6000: 3.406492
# Average loss at step 8000: 3.342373
# Average loss at step 10000: 3.175957
# Nearest to i: you, we, fullerton, accrue, e, cruise, remediation, latino,
# Nearest to united: bradman, padawan, sausage, shatila, moire, spot, annexes, doha,
# Nearest to four: six, three, eight, seven, five, nine, zero, two,
# Nearest to which: that, also, this, snap, often, quail, theophoric, precept,
# Nearest to not: dolby, valentine, deianira, alumnus, still, also, often, breadth,
# Nearest to five: eight, seven, three, four, six, nine, two, zero,
# Nearest to most: despotism, cdb, insert, doubtful, fauna, some, many, condon,
# Nearest to but: iic, haitian, nunavut, pluralized, wes, lewinsky, defect, and,
# Nearest to d: b, maiden, ula, thrives, problematic, berkman, des, exhibiting,
# Nearest to he: she, it, they, who, weber, pedal, afrika, dosage,
# Nearest to two: three, six, five, one, seven, four, eight, nine,
# Nearest to so: glaukos, omnipresent, dnia, wasted, livy, burney, additional, gaians,
# Nearest to been: be, become, jardines, hurled, suspended, was, just, were,
# Nearest to his: her, their, its, the, clubhouse, waldo, s, hash,
# Nearest to has: had, have, forbidding, is, was, uga, gamete, subtract,
# Nearest to these: some, many, such, swordsmanship, circumvented, seceded, deference, peregrine,
# Average loss at step 12000: 3.215779
# Average loss at step 14000: 3.178265
# Average loss at step 16000: 3.199595
# Average loss at step 18000: 3.011787
# Average loss at step 20000: 2.881492
# Nearest to i: we, you, they, g, stringing, lycopene, detested, remediation,
# Nearest to united: padawan, bradman, doha, spot, kolkata, sausage, oakland, earth,
# Nearest to four: seven, six, five, eight, three, nine, zero, two,
# Nearest to which: that, this, also, what, it, but, often, seuss,
# Nearest to not: normally, deianira, still, often, never, we, improperly, bunch,
# Nearest to five: six, four, seven, eight, nine, three, zero, two,
# Nearest to most: more, some, doubtful, insert, many, garnered, dicots, antagonism,
# Nearest to but: however, menachem, when, pluralized, although, and, which, kuna,
# Nearest to d: b, berkman, maiden, aronson, problematic, and, thrives, nihonshoki,
# Nearest to he: she, it, they, there, who, weber, fiancee, ideation,
# Nearest to two: three, four, five, six, eight, nine, seven, one,
# Nearest to so: glaukos, too, omnipresent, livy, burney, wasted, spicy, gehrig,
# Nearest to been: become, be, was, hurled, jardines, suspended, upholding, centimetre,
# Nearest to his: her, their, its, the, emissions, waldo, my, squeak,
# Nearest to has: had, have, is, was, forbidding, gholas, holds, having,
# Nearest to these: such, some, many, those, different, their, several, all,
# Average loss at step 22000: 2.950289
# Average loss at step 24000: 3.083817
# Average loss at step 26000: 2.932516
# Average loss at step 28000: 2.994667
# Average loss at step 30000: 3.046504
# Nearest to i: we, you, stringing, g, ii, cold, fullerton, they,
# Nearest to united: padawan, oakland, nation, athenians, hatti, doha, batsman, kolkata,
# Nearest to four: five, six, seven, eight, three, nine, two, zero,
# Nearest to which: that, this, but, also, where, who, what, typically,
# Nearest to not: often, normally, still, never, we, deianira, pose, nothing,
# Nearest to five: four, six, seven, eight, three, nine, zero, two,
# Nearest to most: more, many, some, dicots, less, peremptory, insert, despotism,
# Nearest to but: however, although, and, which, though, see, finally, menachem,
# Nearest to d: b, nihonshoki, problematic, berkman, thrives, bacterium, aronson, gime,
# Nearest to he: she, it, they, who, weber, there, eventually, subsequently,
# Nearest to two: four, three, one, five, six, seven, eight, nine,
# Nearest to so: too, glaukos, livy, criminality, creature, torrent, robertson, organise,
# Nearest to been: become, be, were, was, jamestown, inefficiencies, recently, jardines,
# Nearest to his: her, their, its, my, your, the, waldo, spec,
# Nearest to has: had, have, is, was, forbidding, holds, acidosis, boreal,
# Nearest to these: such, some, those, many, various, several, different, melcher,
# Average loss at step 32000: 2.938515
# Average loss at step 34000: 2.926996
# Average loss at step 36000: 2.913031
# Average loss at step 38000: 2.841682
# Average loss at step 40000: 2.856148
# Nearest to i: ii, we, you, stringing, g, iii, cold, fullerton,
# Nearest to united: padawan, oakland, nation, hatti, lookahead, sausage, athenians, paula,
# Nearest to four: six, eight, five, three, seven, nine, zero, two,
# Nearest to which: that, who, also, this, typically, what, where, seuss,
# Nearest to not: never, normally, still, always, usually, nothing, often, actually,
# Nearest to five: six, four, seven, eight, three, zero, nine, two,
# Nearest to most: more, many, less, some, dicots, use, malice, hispano,
# Nearest to but: however, although, though, and, menachem, meant, that, which,
# Nearest to d: b, berkman, problematic, coprocessor, gime, maoi, hennig, achaemenid,
# Nearest to he: she, it, they, there, who, never, we, weber,
# Nearest to two: three, four, five, six, eight, seven, one, nine,
# Nearest to so: too, kali, organise, spicy, carey, dearborn, less, flung,
# Nearest to been: become, be, were, recently, was, cements, inefficiencies, jardines,
# Nearest to his: her, their, its, my, your, whose, waldo, the,
# Nearest to has: had, have, was, is, forbidding, having, acidosis, gholas,
# Nearest to these: those, such, several, many, some, propagates, various, eternal,
# Average loss at step 42000: 2.890819
# Average loss at step 44000: 2.893696
# Average loss at step 46000: 2.917940
# Average loss at step 48000: 2.885536
# Average loss at step 50000: 2.756948
# Nearest to i: we, ii, you, they, g, he, iii, she,
# Nearest to united: padawan, oakland, neighboring, hatti, lookahead, athenians, sausage, decayed,
# Nearest to four: six, five, seven, three, eight, nine, two, zero,
# Nearest to which: that, this, also, who, where, usually, often, what,
# Nearest to not: never, normally, still, always, generally, deianira, usually, bunch,
# Nearest to five: six, seven, four, eight, three, nine, zero, two,
# Nearest to most: more, less, many, unaware, particularly, dicots, simplifies, doubtful,
# Nearest to but: however, although, and, though, while, it, surges, voigt,
# Nearest to d: b, berkman, problematic, hennig, upanija, r, coprocessor, digger,
# Nearest to he: she, it, they, there, we, who, weber, then,
# Nearest to two: three, four, seven, five, six, eight, nine, one,
# Nearest to so: too, kali, brun, stags, less, aar, sometimes, spicy,
# Nearest to been: become, be, recently, remained, were, cements, already, was,
# Nearest to his: her, their, my, your, its, the, whose, waldo,
# Nearest to has: had, have, is, was, forbidding, chartres, having, holds,
# Nearest to these: such, some, those, many, several, various, they, both,
# Average loss at step 52000: 2.894064
# Average loss at step 54000: 2.847106
# Average loss at step 56000: 2.845133
# Average loss at step 58000: 2.856385
# Average loss at step 60000: 2.844298
# Nearest to i: ii, g, we, you, cold, iii, vi, remediation,
# Nearest to united: padawan, oakland, lookahead, topol, kolkata, paula, neighboring, nation,
# Nearest to four: six, eight, five, nine, three, seven, zero, two,
# Nearest to which: that, this, what, who, also, typically, based, however,
# Nearest to not: never, normally, still, generally, now, usually, nothing, always,
# Nearest to five: six, four, eight, nine, seven, three, zero, two,
# Nearest to most: more, some, many, particularly, unaware, especially, less, dicots,
# Nearest to but: however, and, although, though, while, see, malted, myles,
# Nearest to d: b, berkman, problematic, l, hennig, p, r, backlight,
# Nearest to he: she, it, they, there, we, who, subsequently, weber,
# Nearest to two: three, six, five, four, eight, nine, one, seven,
# Nearest to so: too, kali, brun, praetorians, spicy, quarries, sometimes, intifada,
# Nearest to been: become, be, were, remained, recently, cements, come, already,
# Nearest to his: her, their, my, its, your, whose, our, waldo,
# Nearest to has: had, have, is, was, contains, having, forbidding, holds,
# Nearest to these: some, those, many, such, several, various, different, list,
# Average loss at step 62000: 2.630811
# Average loss at step 64000: 2.827408
# Average loss at step 66000: 2.822464
# Average loss at step 68000: 2.814584
# Average loss at step 70000: 2.773637
# Nearest to i: we, you, ii, g, they, capcom, he, vi,
# Nearest to united: padawan, oakland, nation, neighboring, lookahead, mayor, paula, same,
# Nearest to four: five, six, eight, three, seven, nine, two, zero,
# Nearest to which: that, this, also, who, typically, what, usually, often,
# Nearest to not: never, still, normally, generally, actually, usually, always, now,
# Nearest to five: six, eight, four, seven, nine, three, zero, two,
# Nearest to most: more, many, less, some, particularly, especially, doubtful, unaware,
# Nearest to but: however, and, although, though, while, or, than, continents,
# Nearest to d: b, problematic, hennig, l, berkman, jutes, upanija, backlight,
# Nearest to he: she, it, they, there, we, who, i, trailers,
# Nearest to two: three, four, six, five, eight, seven, one, nine,
# Nearest to so: too, kali, praetorians, brun, thus, spicy, sometimes, organise,
# Nearest to been: become, be, recently, remained, were, already, come, was,
# Nearest to his: her, their, my, your, its, our, waldo, whose,
# Nearest to has: had, have, was, is, holds, having, contains, forbidding,
# Nearest to these: those, many, such, several, various, some, list, both,
# Average loss at step 72000: 2.853904
# Average loss at step 74000: 2.837301
# Average loss at step 76000: 2.804511
# Average loss at step 78000: 2.764655
# Average loss at step 80000: 2.739468
# Nearest to i: we, ii, you, g, vi, capcom, loyalties, iii,
# Nearest to united: padawan, oakland, nation, neighboring, byzantine, lookahead, topol, paula,
# Nearest to four: six, five, seven, three, eight, nine, two, zero,
# Nearest to which: that, this, what, typically, usually, who, actually, also,
# Nearest to not: normally, never, t, still, actually, now, nor, generally,
# Nearest to five: four, six, eight, seven, three, nine, zero, two,
# Nearest to most: more, less, many, some, especially, unaware, all, groundwork,
# Nearest to but: however, although, though, and, while, where, amongst, including,
# Nearest to d: b, problematic, backlight, berkman, innes, gbp, r, conceivably,
# Nearest to he: she, it, they, there, we, who, trailers, probably,
# Nearest to two: three, four, five, six, seven, eight, nine, one,
# Nearest to so: too, kali, thus, brun, then, praetorians, sometimes, if,
# Nearest to been: become, remained, be, already, recently, was, begun, cements,
# Nearest to his: her, their, my, your, its, our, whose, waldo,
# Nearest to has: had, have, is, was, having, provides, forbidding, holds,
# Nearest to these: some, many, those, several, various, such, numerous, both,
# Average loss at step 82000: 2.789869
# Average loss at step 84000: 2.764359
# Average loss at step 86000: 2.714101
# Average loss at step 88000: 2.696263
# Average loss at step 90000: 2.747248
# Nearest to i: we, you, g, ii, vi, loyalties, kinetochore, capcom,
# Nearest to united: padawan, nation, oakland, neighboring, topol, member, byzantine, lookahead,
# Nearest to four: five, six, seven, three, eight, nine, two, zero,
# Nearest to which: that, this, what, who, typically, also, usually, based,
# Nearest to not: never, normally, actually, still, now, generally, usually, permanently,
# Nearest to five: four, seven, six, three, eight, nine, zero, two,
# Nearest to most: more, especially, less, many, unaware, particularly, dicots, some,
# Nearest to but: however, although, and, though, incorporates, while, she, which,
# Nearest to d: b, backlight, l, quintet, r, filmmaker, p, berkman,
# Nearest to he: she, they, it, there, we, who, subsequently, beckham,
# Nearest to two: four, three, five, six, seven, eight, one, nine,
# Nearest to so: too, kali, thus, sometimes, brun, praetorians, organise, realized,
# Nearest to been: become, be, remained, already, recently, were, come, was,
# Nearest to his: her, their, my, your, its, our, waldo, whose,
# Nearest to has: had, have, is, was, having, provides, forbidding, includes,
# Nearest to these: several, those, various, such, many, some, numerous, instead,
# Average loss at step 92000: 2.750191
# Average loss at step 94000: 2.659328
# Average loss at step 96000: 2.691505
# Average loss at step 98000: 2.663162
# Average loss at step 100000: 2.685850
# Nearest to i: we, you, ii, vi, g, kinetochore, iii, iv,
# Nearest to united: padawan, oakland, nation, neighboring, dicotyledons, byzantine, topol, doha,
# Nearest to four: five, six, seven, three, eight, nine, two, zero,
# Nearest to which: that, typically, also, this, what, usually, who, where,
# Nearest to not: never, now, generally, still, actually, always, normally, usually,
# Nearest to five: seven, four, six, eight, nine, three, zero, two,
# Nearest to most: more, many, less, especially, particularly, unaware, some, dicots,
# Nearest to but: however, although, and, though, which, ate, probably, landtag,
# Nearest to d: b, quintet, vero, cha, fictionalised, berkman, problematic, backlight,
# Nearest to he: she, it, they, there, who, we, eventually, originally,
# Nearest to two: three, four, five, six, seven, eight, one, nine,
# Nearest to so: too, thus, sometimes, brun, praetorians, kali, suggesting, how,
# Nearest to been: become, be, remained, were, recently, come, already, was,
# Nearest to his: her, their, my, its, your, whose, our, the,
# Nearest to has: had, have, is, having, was, chartres, includes, forbidding,
# Nearest to these: those, several, various, both, some, such, numerous, many,

# %% [markdown]
# I trained this model by concatenating the word vectors, and by taking the sum of the vectors.  Concatenating the vectors resulted in a loss of ~2.01, while the sum loss was ~2.69 after 100k steps.  Both methods produced reasonable tSNE plots.

# %%
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])
words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
